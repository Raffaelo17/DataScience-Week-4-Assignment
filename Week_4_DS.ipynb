# %%
import pandas as pd
import numpy as np

# %%
pd.set_option("display.max_rows", 10)
pd.read_csv('cwurData.csv')
# Out:
#       world_rank                            institution         country  \
# 0              1                     Harvard University             USA
# 1              2  Massachusetts Institute of Technology             USA
# 2              3                    Stanford University             USA
# 3              4                University of Cambridge  United Kingdom
# 4              5     California Institute of Technology             USA
# ...          ...                                    ...             ...
# 2195         996              University of the Algarve        Portugal
# 2196         997                  Alexandria University           Egypt
# 2197         998            Federal University of Ceará          Brazil
# 2198         999                 University of A Coruña           Spain
# 2199        1000        China Pharmaceutical University           China
#
#       national_rank  quality_of_education  alumni_employment  \
# ...

# %%
df = pd.read_csv('cwurData.csv')

df.head(10)
# Out:
#    world_rank                            institution         country  \
# 0           1                     Harvard University             USA
# 1           2  Massachusetts Institute of Technology             USA
# 2           3                    Stanford University             USA
# 3           4                University of Cambridge  United Kingdom
# 4           5     California Institute of Technology             USA
# 5           6                   Princeton University             USA
# 6           7                   University of Oxford  United Kingdom
# 7           8                        Yale University             USA
# 8           9                    Columbia University             USA
# 9          10     University of California, Berkeley             USA
#
#    national_rank  quality_of_education  alumni_employment  quality_of_faculty  \
# 0              1                     7                  9                   1
# ...

# %%
pd.read_csv('cwurData.csv')
df2 = pd.read_csv('timesData.csv')
df2.head(10)
# Out:
#   world_rank                        university_name                   country  \
# 0          1                     Harvard University  United States of America
# 1          2     California Institute of Technology  United States of America
# 2          3  Massachusetts Institute of Technology  United States of America
# 3          4                    Stanford University  United States of America
# 4          5                   Princeton University  United States of America
# 5          6                University of Cambridge            United Kingdom
# 6          6                   University of Oxford            United Kingdom
# 7          8     University of California, Berkeley  United States of America
# 8          9                Imperial College London            United Kingdom
# 9         10                        Yale University  United States of America
#
#    teaching international  research  citations income total_score  \
# ...

# %%
df.isnull().sum()
# Out:
# world_rank                0
# institution               0
# country                   0
# national_rank             0
# quality_of_education      0
#                        ...
# citations                 0
# broad_impact            200
# patents                   0
# score                     0
# year                      0
# Length: 14, dtype: int64

# %%
df_merge=df.merge(df2, left_on='institution', right_on='university_name')
df_merge = df_merge[0:10]
df = df_merge
df
# Out:
#    world_rank_x         institution country_x  national_rank  \
# 0             1  Harvard University       USA              1
# 1             1  Harvard University       USA              1
# 2             1  Harvard University       USA              1
# 3             1  Harvard University       USA              1
# 4             1  Harvard University       USA              1
# 5             1  Harvard University       USA              1
# 6             1  Harvard University       USA              1
# 7             1  Harvard University       USA              1
# 8             1  Harvard University       USA              1
# 9             1  Harvard University       USA              1
#
#    quality_of_education  alumni_employment  quality_of_faculty  publications  \
# 0                     7                  9                   1             1
# 1                     7                  9                   1             1
# ...

# %%
df.query('country_x < country_y')
# Out:
#    world_rank_x         institution country_x  national_rank  \
# 0             1  Harvard University       USA              1
# 1             1  Harvard University       USA              1
# 2             1  Harvard University       USA              1
# 3             1  Harvard University       USA              1
# 4             1  Harvard University       USA              1
# 5             1  Harvard University       USA              1
# 6             1  Harvard University       USA              1
# 7             1  Harvard University       USA              1
# 8             1  Harvard University       USA              1
# 9             1  Harvard University       USA              1
#
#    quality_of_education  alumni_employment  quality_of_faculty  publications  \
# 0                     7                  9                   1             1
# 1                     7                  9                   1             1
# ...

# %%
np.random.seed(50)
col_name=['country_x','country_y']
mask = np.random.choice([True, False], size=df[col_name].shape)
mask[mask.all(1),-1] = 0
print(mask)
df[col_name]=df[col_name].mask(mask)
df
# Out:
# [[ True False]
#  [False False]
#  [False  True]
#  [ True False]
#  [False  True]
#  [ True False]
#  [False  True]
#  [False  True]
#  [False False]
#  [ True False]]
#    world_rank_x         institution country_x  national_rank  \
# 0             1  Harvard University       NaN              1
# 1             1  Harvard University       USA              1
# 2             1  Harvard University       USA              1
# 3             1  Harvard University       NaN              1
# 4             1  Harvard University       USA              1
# 5             1  Harvard University       NaN              1
# 6             1  Harvard University       USA              1
# 7             1  Harvard University       USA              1
# 8             1  Harvard University       USA              1
# 9             1  Harvard University       NaN              1
#
#    quality_of_education  alumni_employment  quality_of_faculty  publications  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10 entries, 0 to 9
# Data columns (total 28 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   world_rank_x            10 non-null     int64
#  1   institution             10 non-null     object
#  2   country_x               6 non-null      object
#  3   national_rank           10 non-null     int64
#  4   quality_of_education    10 non-null     int64
#  5   alumni_employment       10 non-null     int64
#  6   quality_of_faculty      10 non-null     int64
#  7   publications            10 non-null     int64
#  8   influence               10 non-null     int64
#  9   citations_x             10 non-null     int64
#  10  broad_impact            0 non-null      float64
#  11  patents                 10 non-null     int64
#  12  score                   10 non-null     float64
#  13  year_x                  10 non-null     int64
# ...

# %%
df.rename(columns={"university_name": "Name of University"})
# Out:
#    world_rank_x         institution country_x  national_rank  \
# 0             1  Harvard University       NaN              1
# 1             1  Harvard University       USA              1
# 2             1  Harvard University       USA              1
# 3             1  Harvard University       NaN              1
# 4             1  Harvard University       USA              1
# 5             1  Harvard University       NaN              1
# 6             1  Harvard University       USA              1
# 7             1  Harvard University       USA              1
# 8             1  Harvard University       USA              1
# 9             1  Harvard University       NaN              1
#
#    quality_of_education  alumni_employment  quality_of_faculty  publications  \
# 0                     7                  9                   1             1
# 1                     7                  9                   1             1
# ...

# %%
df.set_index('institution')
# Out:
#                     world_rank_x country_x  national_rank  \
# institution
# Harvard University             1       NaN              1
# Harvard University             1       USA              1
# Harvard University             1       USA              1
# Harvard University             1       NaN              1
# Harvard University             1       USA              1
# Harvard University             1       NaN              1
# Harvard University             1       USA              1
# Harvard University             1       USA              1
# Harvard University             1       USA              1
# Harvard University             1       NaN              1
#
#                     quality_of_education  alumni_employment  \
# institution
# Harvard University                     7                  9
# Harvard University                     7                  9
# Harvard University                     7                  9
# ...

# %%
df.melt()
# Out:
#          variable value
# 0    world_rank_x     1
# 1    world_rank_x     1
# 2    world_rank_x     1
# 3    world_rank_x     1
# 4    world_rank_x     1
# ..            ...   ...
# 275        year_y  2016
# 276        year_y  2011
# 277        year_y  2012
# 278        year_y  2013
# 279        year_y  2014
#
# [280 rows x 2 columns]

# %%
df.apply(lambda x: [1, 2], axis=1, result_type='expand')
# Out:
#    0  1
# 0  1  2
# 1  1  2
# 2  1  2
# 3  1  2
# 4  1  2
# 5  1  2
# 6  1  2
# 7  1  2
# 8  1  2
# 9  1  2

# %%
df.dropna(how='all')
# Out:
#    world_rank_x         institution country_x  national_rank  \
# 0             1  Harvard University       NaN              1
# 1             1  Harvard University       USA              1
# 2             1  Harvard University       USA              1
# 3             1  Harvard University       NaN              1
# 4             1  Harvard University       USA              1
# 5             1  Harvard University       NaN              1
# 6             1  Harvard University       USA              1
# 7             1  Harvard University       USA              1
# 8             1  Harvard University       USA              1
# 9             1  Harvard University       NaN              1
#
#    quality_of_education  alumni_employment  quality_of_faculty  publications  \
# 0                     7                  9                   1             1
# 1                     7                  9                   1             1
# ...

# %%
df.fillna('missing')
# Out:
#    world_rank_x         institution country_x  national_rank  \
# 0             1  Harvard University   missing              1
# 1             1  Harvard University       USA              1
# 2             1  Harvard University       USA              1
# 3             1  Harvard University   missing              1
# 4             1  Harvard University       USA              1
# 5             1  Harvard University   missing              1
# 6             1  Harvard University       USA              1
# 7             1  Harvard University       USA              1
# 8             1  Harvard University       USA              1
# 9             1  Harvard University   missing              1
#
#    quality_of_education  alumni_employment  quality_of_faculty  publications  \
# 0                     7                  9                   1             1
# 1                     7                  9                   1             1
# ...

# %%
df.groupby(['institution']).mean()
# Out:
# <ipython-input-440-1db25aba9c13>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['institution']).mean()
#                     world_rank_x  national_rank  quality_of_education  \
# institution
# Harvard University           1.0            1.0                   4.6
#
#                     alumni_employment  quality_of_faculty  publications  \
# institution
# Harvard University                5.8                 1.0           1.0
#
#                     influence  citations_x  broad_impact  patents  score  \
# institution
# Harvard University        1.0          1.0           NaN      5.8  100.0
#
#                     year_x  teaching  research  citations_y  \
# institution
# Harvard University  2012.4     94.79      98.4        99.25
#
# ...

# %%
df.agg("mean", axis="columns")
# Out:
# <ipython-input-441-41a31b8a6513>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.agg("mean", axis="columns")
# Series([], dtype: float64)
